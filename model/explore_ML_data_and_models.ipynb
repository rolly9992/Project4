# %%
'''TODO 
look at both y variables total and per quarter 
both better_than_spy 
and return (or future price) #add a better_return_than_spy?

'''
# Out:
# 'TODO \nlook at both y variables total and per quarter \nboth better_than_spy \nand return (or future price) #add a better_return_than_spy?\n\n'

# %%
import pandas as pd 
pd.options.mode.chained_assignment = None
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing, svm
from sklearn.model_selection import cross_validate
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import max_error, mean_absolute_error, mean_squared_error, median_absolute_error, r2_score
import seaborn as sns

import matplotlib.pyplot as plt
from scipy import stats
pd.options.display.float_format = '{:20,.2f}'.format
import sys 
from sklearn import svm

# %%
#df = pd.read_excel('/home/milo/Documents/Project4/data/machineLearningData.xlsx')
df = pd.read_excel('ml_data.xlsx')
df = df.set_index('ticker')
df.shape
# Out:
# (2480, 107)

# %%
#note the sequences are simply shorthand for the 5 quarters we are looking at (we can't test the last one unless we 
# get another quarter's data after that... )
sequences = [0,1,2,3,4]

# %%
df.head()
# Out:
#         gics_sector  totalAssets  totalCurrentAssets  \
# ticker
# MMM     Industrials  45634000000         14514000000
# MMM     Industrials  46176000000         14895000000
# MMM     Industrials  46455000000         14688000000
# MMM     Industrials  46886000000         14963000000
# MMM     Industrials  48880000000         15754000000
#
#         cashAndCashEquivalentsAtCarryingValue  cashAndShortTermInvestments  \
# ticker
# MMM                                2722000000             2,722,000,000.00
# MMM                                3404000000             3,404,000,000.00
# MMM                                3655000000             3,655,000,000.00
# MMM                                3824000000             3,824,000,000.00
# MMM                                4258000000             4,258,000,000.00
#
#                   inventory  currentNetReceivables  totalNonCurrentAssets  \
# ticker
# MMM        5,645,000,000.00       4,914,000,000.00      31,120,000,000.00
# MMM        5,615,000,000.00       4,722,000,000.00      31,281,000,000.00
# MMM        5,372,000,000.00       4,532,000,000.00      34,124,000,000.00
# MMM        5,306,000,000.00       4,638,000,000.00      31,923,000,000.00
# MMM        5,280,000,000.00       4,947,000,000.00      33,126,000,000.00
#
#         propertyPlantEquipment  accumulatedDepreciationAmortizationPPE  ...  \
# ticker                                                                  ...
# MMM                 9319000000                       17,694,000,000.00  ...
# MMM                 9196000000                       17,470,000,000.00  ...
# MMM                 9178000000                       16,820,000,000.00  ...
# MMM                 9247000000                       17,049,000,000.00  ...
# MMM                 9211000000                       17,248,000,000.00  ...
#
#         days_in_inventory_ratio   gross_margin_ratio  operating_margin_ratio  \
# ticker
# MMM                      386.00                46.27                    1.41
# MMM                      426.49                 1.01                    1.08
# MMM                      443.13                 6.46                    1.17
# MMM                      423.43                 3.50                    1.27
# MMM                      418.81                -0.54                    1.37
#
#                   roa_ratio            roe_ratio  sequence  \
# ticker
# MMM                    0.00                 0.01         0
# MMM                    0.08                 0.27         1
# MMM                    0.01                 0.04         2
# MMM                    0.02                 0.06         3
# MMM                   -0.14                -0.88         4
#
#         rolling62_adjustedclose  next_rolling62_adjustedclose  \
# ticker
# MMM                      107.67                         98.77
# MMM                       98.77                         92.93
# MMM                       92.93                         86.89
# MMM                       86.89                         79.38
# MMM                       79.38                         81.46
#
#                      return  better_than_spy
# ticker
# MMM                   -0.08                0
# MMM                   -0.06                0
# MMM                   -0.07                0
# MMM                   -0.09                0
# MMM                    0.03                0
#
# [5 rows x 107 columns]

# %%
#get the numerical variables
num_vars = df.select_dtypes(include=['float','int']).columns
dfnum=df[num_vars]
corr = dfnum.corr()
corr #we will need to consider correlated features
# Out:
#                                                totalAssets  \
# totalAssets                                           1.00
# totalCurrentAssets                                    0.84
# cashAndCashEquivalentsAtCarryingValue                 0.93
# cashAndShortTermInvestments                           0.91
# inventory                                            -0.76
# ...                                                    ...
# sequence                                              0.00
# rolling62_adjustedclose                              -0.05
# next_rolling62_adjustedclose                         -0.05
# return                                               -0.03
# better_than_spy                                      -0.02
#
#                                         totalCurrentAssets  \
# totalAssets                                           0.84
# totalCurrentAssets                                    1.00
# cashAndCashEquivalentsAtCarryingValue                 0.82
# cashAndShortTermInvestments                           0.91
# inventory                                            -0.65
# ...                                                    ...
# sequence                                              0.00
# rolling62_adjustedclose                              -0.02
# next_rolling62_adjustedclose                         -0.02
# return                                               -0.00
# better_than_spy                                       0.00
#
#                                        cashAndCashEquivalentsAtCarryingValue  \
# totalAssets                                                             0.93
# totalCurrentAssets                                                      0.82
# cashAndCashEquivalentsAtCarryingValue                                   1.00
# cashAndShortTermInvestments                                             0.92
# inventory                                                              -0.87
# ...                                                                      ...
# sequence                                                                0.01
# rolling62_adjustedclose                                                -0.01
# next_rolling62_adjustedclose                                           -0.01
# return                                                                 -0.00
# better_than_spy                                                        -0.00
#
#                                        cashAndShortTermInvestments  \
# totalAssets                                                   0.91
# totalCurrentAssets                                            0.91
# cashAndCashEquivalentsAtCarryingValue                         0.92
# cashAndShortTermInvestments                                   1.00
# inventory                                                    -0.78
# ...                                                            ...
# sequence                                                      0.01
# rolling62_adjustedclose                                      -0.01
# next_rolling62_adjustedclose                                 -0.01
# return                                                       -0.00
# better_than_spy                                               0.00
#
#                                                  inventory  \
# totalAssets                                          -0.76
# totalCurrentAssets                                   -0.65
# cashAndCashEquivalentsAtCarryingValue                -0.87
# cashAndShortTermInvestments                          -0.78
# inventory                                             1.00
# ...                                                    ...
# sequence                                             -0.00
# rolling62_adjustedclose                               0.01
# next_rolling62_adjustedclose                          0.01
# return                                                0.00
# better_than_spy                                       0.00
#
#                                        currentNetReceivables  \
# totalAssets                                             0.13
# totalCurrentAssets                                      0.28
# cashAndCashEquivalentsAtCarryingValue                   0.04
# cashAndShortTermInvestments                             0.12
# inventory                                               0.03
# ...                                                      ...
# sequence                                               -0.00
# rolling62_adjustedclose                                -0.03
# next_rolling62_adjustedclose                           -0.03
# return                                                  0.00
# better_than_spy                                        -0.01
#
#                                        totalNonCurrentAssets  \
# totalAssets                                             0.30
# totalCurrentAssets                                      0.39
# cashAndCashEquivalentsAtCarryingValue                   0.18
# cashAndShortTermInvestments                             0.25
# inventory                                              -0.08
# ...                                                      ...
# sequence                                                0.01
# rolling62_adjustedclose                                -0.05
# next_rolling62_adjustedclose                           -0.06
# return                                                 -0.05
# better_than_spy                                        -0.06
#
#                                        propertyPlantEquipment  \
# totalAssets                                              0.15
# totalCurrentAssets                                       0.23
# cashAndCashEquivalentsAtCarryingValue                    0.07
# cashAndShortTermInvestments                              0.12
# inventory                                                0.01
# ...                                                       ...
# sequence                                                 0.01
# rolling62_adjustedclose                                 -0.08
# next_rolling62_adjustedclose                            -0.08
# return                                                  -0.03
# better_than_spy                                         -0.06
#
#                                        accumulatedDepreciationAmortizationPPE  \
# totalAssets                                                              0.11
# totalCurrentAssets                                                       0.17
# cashAndCashEquivalentsAtCarryingValue                                    0.03
# cashAndShortTermInvestments                                              0.06
# inventory                                                                0.03
# ...                                                                       ...
# sequence                                                                 0.01
# rolling62_adjustedclose                                                 -0.06
# next_rolling62_adjustedclose                                            -0.06
# return                                                                  -0.03
# better_than_spy                                                         -0.04
#
#                                           intangibleAssets  ...  \
# totalAssets                                           0.28  ...
# totalCurrentAssets                                    0.30  ...
# cashAndCashEquivalentsAtCarryingValue                 0.16  ...
# cashAndShortTermInvestments                           0.23  ...
# inventory                                            -0.06  ...
# ...                                                    ...  ...
# sequence                                              0.01  ...
# rolling62_adjustedclose                              -0.03  ...
# next_rolling62_adjustedclose                         -0.03  ...
# return                                               -0.06  ...
# better_than_spy                                      -0.02  ...
#
#                                        days_in_inventory_ratio  \
# totalAssets                                              -0.07
# totalCurrentAssets                                       -0.07
# cashAndCashEquivalentsAtCarryingValue                    -0.06
# cashAndShortTermInvestments                              -0.06
# inventory                                                 0.08
# ...                                                        ...
# sequence                                                  0.01
# rolling62_adjustedclose                                   0.00
# next_rolling62_adjustedclose                              0.00
# return                                                    0.01
# better_than_spy                                           0.02
#
#                                         gross_margin_ratio  \
# totalAssets                                          -0.01
# totalCurrentAssets                                   -0.02
# cashAndCashEquivalentsAtCarryingValue                -0.01
# cashAndShortTermInvestments                          -0.01
# inventory                                             0.00
# ...                                                    ...
# sequence                                              0.03
# rolling62_adjustedclose                              -0.02
# next_rolling62_adjustedclose                         -0.02
# return                                                0.02
# better_than_spy                                       0.02
#
#                                        operating_margin_ratio  \
# totalAssets                                             -0.01
# totalCurrentAssets                                      -0.01
# cashAndCashEquivalentsAtCarryingValue                   -0.01
# cashAndShortTermInvestments                             -0.01
# inventory                                               -0.00
# ...                                                       ...
# sequence                                                 0.04
# rolling62_adjustedclose                                 -0.00
# next_rolling62_adjustedclose                            -0.00
# return                                                   0.03
# better_than_spy                                          0.03
#
#                                                  roa_ratio  \
# totalAssets                                          -0.13
# totalCurrentAssets                                   -0.07
# cashAndCashEquivalentsAtCarryingValue                -0.08
# cashAndShortTermInvestments                          -0.07
# inventory                                             0.08
# ...                                                    ...
# sequence                                             -0.03
# rolling62_adjustedclose                               0.24
# next_rolling62_adjustedclose                          0.24
# return                                                0.13
# better_than_spy                                       0.12
#
#                                                  roe_ratio  \
# totalAssets                                           0.00
# totalCurrentAssets                                    0.01
# cashAndCashEquivalentsAtCarryingValue                 0.00
# cashAndShortTermInvestments                           0.00
# inventory                                             0.00
# ...                                                    ...
# sequence                                             -0.02
# rolling62_adjustedclose                               0.02
# next_rolling62_adjustedclose                          0.02
# return                                                0.00
# better_than_spy                                       0.02
#
#                                                   sequence  \
# totalAssets                                           0.00
# totalCurrentAssets                                    0.00
# cashAndCashEquivalentsAtCarryingValue                 0.01
# cashAndShortTermInvestments                           0.01
# inventory                                            -0.00
# ...                                                    ...
# sequence                                              1.00
# rolling62_adjustedclose                               0.02
# next_rolling62_adjustedclose                          0.03
# return                                                0.19
# better_than_spy                                      -0.14
#
#                                        rolling62_adjustedclose  \
# totalAssets                                              -0.05
# totalCurrentAssets                                       -0.02
# cashAndCashEquivalentsAtCarryingValue                    -0.01
# cashAndShortTermInvestments                              -0.01
# inventory                                                 0.01
# ...                                                        ...
# sequence                                                  0.02
# rolling62_adjustedclose                                   1.00
# next_rolling62_adjustedclose                              1.00
# return                                                    0.04
# better_than_spy                                           0.05
#
#                                        next_rolling62_adjustedclose  \
# totalAssets                                                   -0.05
# totalCurrentAssets                                            -0.02
# cashAndCashEquivalentsAtCarryingValue                         -0.01
# cashAndShortTermInvestments                                   -0.01
# inventory                                                      0.01
# ...                                                             ...
# sequence                                                       0.03
# rolling62_adjustedclose                                        1.00
# next_rolling62_adjustedclose                                   1.00
# return                                                         0.09
# better_than_spy                                                0.09
#
#                                                     return  \
# totalAssets                                          -0.03
# totalCurrentAssets                                   -0.00
# cashAndCashEquivalentsAtCarryingValue                -0.00
# cashAndShortTermInvestments                          -0.00
# inventory                                             0.00
# ...                                                    ...
# sequence                                              0.19
# rolling62_adjustedclose                               0.04
# next_rolling62_adjustedclose                          0.09
# return                                                1.00
# better_than_spy                                       0.69
#
#                                            better_than_spy
# totalAssets                                          -0.02
# totalCurrentAssets                                    0.00
# cashAndCashEquivalentsAtCarryingValue                -0.00
# cashAndShortTermInvestments                           0.00
# inventory                                             0.00
# ...                                                    ...
# sequence                                             -0.14
# rolling62_adjustedclose                               0.05
# next_rolling62_adjustedclose                          0.09
# return                                                0.69
# better_than_spy                                       1.00
#
# [106 rows x 106 columns]

# %%
df.describe()
# Out:
#                totalAssets   totalCurrentAssets  \
# count             2,480.00             2,480.00
# mean     89,473,167,460.48    17,847,657,202.02
# std     286,068,426,152.08    47,215,112,355.66
# min         764,708,000.00           921,000.00
# 25%      12,174,614,500.00     2,545,800,000.00
# 50%      26,125,500,000.00     5,527,607,000.00
# 75%      63,383,500,000.00    14,023,750,000.00
# max   3,868,240,000,000.00   673,969,000,000.00
#
#        cashAndCashEquivalentsAtCarryingValue  cashAndShortTermInvestments  \
# count                               2,480.00                     2,480.00
# mean                        6,812,045,140.32             9,235,838,817.24
# std                        35,039,140,829.30            40,971,044,626.28
# min                               921,000.00                   921,000.00
# 25%                           400,738,250.00               437,917,500.00
# 50%                         1,168,000,000.00             1,301,961,500.00
# 75%                         3,598,360,000.00             4,462,750,000.00
# max                       641,860,000,000.00           669,260,000,000.00
#
#                   inventory  currentNetReceivables  totalNonCurrentAssets  \
# count              2,480.00               2,480.00               2,480.00
# mean      -9,967,041,525.50       3,203,949,249.21      27,351,805,926.98
# std      115,689,587,131.09       6,824,570,865.94      42,201,339,413.79
# min   -1,886,356,000,000.00        -768,000,000.00             288,000.00
# 25%          107,617,500.00         368,493,000.00       5,231,225,000.00
# 50%          864,426,000.00       1,148,629,500.00      12,242,000,000.00
# 75%        2,753,250,000.00       2,957,700,000.00      30,381,750,000.00
# max      173,717,000,000.00      64,778,000,000.00     358,017,000,000.00
#
#        propertyPlantEquipment  accumulatedDepreciationAmortizationPPE  \
# count                2,480.00                                2,480.00
# mean        11,319,419,354.13                        8,400,159,933.37
# std         24,152,875,001.99                       22,426,569,000.02
# min        -13,650,000,000.00                       -1,240,100,000.00
# 25%            727,250,000.00                          572,750,000.00
# 50%          2,492,500,000.00                        2,098,100,000.00
# 75%          9,725,000,000.00                        7,191,500,000.00
# max        209,159,000,000.00                      273,255,500,000.00
#
#           intangibleAssets  ...  days_in_inventory_ratio   gross_margin_ratio  \
# count             2,480.00  ...                 2,480.00             2,480.00
# mean     12,169,016,821.33  ...                  -396.77                 5.23
# std      22,719,443,301.13  ...               307,120.62                65.17
# min        -399,000,000.00  ...            -3,935,065.00            -1,251.20
# 25%         991,500,000.00  ...                    38.87                 1.45
# 50%       4,477,756,000.00  ...                   253.15                 2.69
# 75%      11,557,975,000.00  ...                   524.51                 4.88
# max     221,943,000,000.00  ...            10,639,020.00             2,491.61
#
#        operating_margin_ratio            roa_ratio            roe_ratio  \
# count                2,480.00             2,480.00             2,480.00
# mean                     2.16                 0.02                 0.02
# std                     41.34                 0.02                 2.16
# min                   -217.89                -0.27               -70.33
# 25%                      1.06                 0.01                 0.02
# 50%                      1.32                 0.01                 0.04
# 75%                      1.54                 0.03                 0.08
# max                  1,864.26                 0.21                29.20
#
#                   sequence  rolling62_adjustedclose  \
# count             2,480.00                 2,480.00
# mean                  2.00                   156.80
# std                   1.41                   283.08
# min                   0.00                     4.56
# 25%                   1.00                    54.53
# 50%                   2.00                    96.92
# 75%                   3.00                   183.23
# max                   4.00                 5,820.19
#
#        next_rolling62_adjustedclose               return      better_than_spy
# count                      2,480.00             2,480.00             2,480.00
# mean                         161.01                 0.02                 0.47
# std                          302.98                 0.11                 0.50
# min                            5.75                -0.51                 0.00
# 25%                           54.74                -0.05                 0.00
# 50%                           98.49                 0.01                 0.00
# 75%                          189.19                 0.08                 1.00
# max                        6,209.09                 0.86                 1.00
#
# [8 rows x 106 columns]

# %%
nulls = df.isna().sum()
nulls.max() #no nulls after manipulation
# Out:
# 0

# %% [markdown]
# # HISTOGRAMS OF NORMALIZED NUMERICAL COLUMNS

# %%
#plot the non boolean numerical variables to look at distributions 
#NOTE some distributions look squished due to the "cookie cutter" method to quickly look at all of them. 

booleanvars = [col for col in dfnum.columns if set(dfnum[col].unique()).issubset({0,1})]
#print(len(booleanvars))
nonbooleanvars = list(set(num_vars)-set(booleanvars))
cols = dfnum[nonbooleanvars].columns
dfnum_normalized = (dfnum - dfnum.mean())/dfnum.std()
print(len(cols))

#plot the non boolean numerical variables to look at distributions 
#NOTE some distributions look squished due to the "cookie cutter" method to quickly look at all of them. 
cols = dfnum[nonbooleanvars].columns

#print out histograms of the nonboolean numeric columns in sets of 4 
for i in range(26):
    temp = dfnum_normalized[cols[4*i:4*i+4]]
    temp.hist(bins=100)
# #get the remaining leftover column... 
temp = dfnum[cols[-1:]]
temp.hist()
# Out:
# 105
# /home/milo/miniconda3/envs/project4/lib/python3.11/site-packages/pandas/plotting/_matplotlib/tools.py:233: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = plt.figure(**fig_kw)
# array([[<Axes: title={'center': 'costofGoodsAndServicesSold'}>]],
#       dtype=object)

# %%
desc = dfnum_normalized.describe()
desc = desc.T
#for i in range(0,100,20):
desc.sort_values('max',ascending=False,inplace=True)
desc #.iloc[i:i+5]
# Out:
#                                                      count  \
# inventory_turnover_ratio                          2,480.00
# cash_ratio                                        2,480.00
# paymentsForOperatingActivities                    2,480.00
# operating_margin_ratio                            2,480.00
# paymentsForRepurchaseOfPreferredStock             2,480.00
# ...                                                    ...
# proceedsFromRepurchaseOfEquity                    2,480.00
# inventory                                         2,480.00
# averageInventory                                  2,480.00
# sequence                                          2,480.00
# better_than_spy                                   2,480.00
#
#                                                       mean  \
# inventory_turnover_ratio                              0.00
# cash_ratio                                           -0.00
# paymentsForOperatingActivities                       -0.00
# operating_margin_ratio                                0.00
# paymentsForRepurchaseOfPreferredStock                -0.00
# ...                                                    ...
# proceedsFromRepurchaseOfEquity                        0.00
# inventory                                            -0.00
# averageInventory                                      0.00
# sequence                                              0.00
# better_than_spy                                       0.00
#
#                                                        std  \
# inventory_turnover_ratio                              1.00
# cash_ratio                                            1.00
# paymentsForOperatingActivities                        1.00
# operating_margin_ratio                                1.00
# paymentsForRepurchaseOfPreferredStock                 1.00
# ...                                                    ...
# proceedsFromRepurchaseOfEquity                        1.00
# inventory                                             1.00
# averageInventory                                      1.00
# sequence                                              1.00
# better_than_spy                                       1.00
#
#                                                        min  \
# inventory_turnover_ratio                             -0.02
# cash_ratio                                           -0.06
# paymentsForOperatingActivities                       -0.50
# operating_margin_ratio                               -5.32
# paymentsForRepurchaseOfPreferredStock                -0.14
# ...                                                    ...
# proceedsFromRepurchaseOfEquity                      -16.96
# inventory                                           -16.22
# averageInventory                                    -15.97
# sequence                                             -1.41
# better_than_spy                                      -0.94
#
#                                                        25%  \
# inventory_turnover_ratio                             -0.02
# cash_ratio                                           -0.05
# paymentsForOperatingActivities                       -0.10
# operating_margin_ratio                               -0.03
# paymentsForRepurchaseOfPreferredStock                -0.05
# ...                                                    ...
# proceedsFromRepurchaseOfEquity                        0.05
# inventory                                             0.09
# averageInventory                                      0.09
# sequence                                             -0.71
# better_than_spy                                      -0.94
#
#                                                        50%  \
# inventory_turnover_ratio                             -0.02
# cash_ratio                                           -0.05
# paymentsForOperatingActivities                       -0.09
# operating_margin_ratio                               -0.02
# paymentsForRepurchaseOfPreferredStock                -0.05
# ...                                                    ...
# proceedsFromRepurchaseOfEquity                        0.24
# inventory                                             0.09
# averageInventory                                      0.09
# sequence                                              0.00
# better_than_spy                                      -0.94
#
#                                                        75%  \
# inventory_turnover_ratio                             -0.02
# cash_ratio                                           -0.04
# paymentsForOperatingActivities                       -0.07
# operating_margin_ratio                               -0.01
# paymentsForRepurchaseOfPreferredStock                -0.05
# ...                                                    ...
# proceedsFromRepurchaseOfEquity                        0.26
# inventory                                             0.11
# averageInventory                                      0.11
# sequence                                              0.71
# better_than_spy                                       1.06
#
#                                                        max
# inventory_turnover_ratio                             49.78
# cash_ratio                                           48.38
# paymentsForOperatingActivities                       46.19
# operating_margin_ratio                               45.04
# paymentsForRepurchaseOfPreferredStock                41.29
# ...                                                    ...
# proceedsFromRepurchaseOfEquity                        2.03
# inventory                                             1.59
# averageInventory                                      1.58
# sequence                                              1.41
# better_than_spy                                       1.06
#
# [106 rows x 8 columns]

# %%
def prep_for_classifier(df):
    df = df[df['sequence']!=5]

    #keeping return in ML would mean data leakage. 
    df = df.drop('return',axis=1) #we will use this later. But we would not know this in advance. 
    #pulling out sequence separately. we do not want to normalize this particular column. 
    seqvar = pd.DataFrame(df['sequence'])
    df = df.drop('sequence',axis=1)
    df = df.drop('next_rolling62_adjustedclose',axis=1) #we will use this for the regressor models 
    
    #borrowing some code from project 1 
    num_vars = df.select_dtypes(include=['float','int']).columns
    cat_vars = df.select_dtypes(include=['object']).columns
    dfnum = df[num_vars]
    booleanvars = [col for col in dfnum.columns if set(dfnum[col].unique()).issubset({0,1})]
    #print(len(booleanvars))
    nonbooleanvars = list(set(num_vars)-set(booleanvars))
    

    #create dummy variables for the categorical variable set then drop the original categorical non numerical columns
    l = [df[cat_vars]]
    for i in range(len(cat_vars)):
        temp = cat_vars[i]
        catout = pd.get_dummies(df[temp],prefix=temp,prefix_sep='_',dummy_na=True,drop_first=True)
        l.append(catout)
    dfcat=pd.concat(l,axis=1)
    dfcat=dfcat.drop(columns=cat_vars,axis=0)
    #print(df.shape)
    #print(dfcat.shape) #expecting an increase due to adding dummies. 
    cat_cols = dfcat.columns.tolist()
    for i in range(len(cat_cols)):
        dfcat[cat_cols[i]] = dfcat[cat_cols[i]].astype(int)
    
    df_bool = df[booleanvars]
    df_nonbool = df[nonbooleanvars]
    df_nonbool = (df_nonbool-df_nonbool.mean())/df_nonbool.std()
    new_df = pd.concat([dfcat,seqvar,df_nonbool,df_bool],axis=1)

    return new_df
def get_X_y_data(df,sequence):
    #print(df.shape)
    
    df = df[df['sequence']==sequence]
    #print(df.shape)
    df = df.drop('sequence',axis=1)
           
    X = df.iloc[:,:-1]

    #X.to_excel('X.xlsx')    
    #print(X.columns.tolist())
    y = df.iloc[:,-1:]
    y=y['better_than_spy'].values
    return X,y

# %%
mod_df= prep_for_classifier(df=df)
print(mod_df.shape)
print(mod_df['sequence'].unique())
# Out:
# (2480, 115)
# [0 1 2 3 4]

# %%
X,y=get_X_y_data(mod_df,sequence=1)
print(X.shape)
print(y.shape)
# Out:
# (496, 113)
# (496,)

# %%
def evaluate_classifier_model(model, X_test, Y_test): #, category_names=None):
    '''INPUT
    the machine learning model we built earlier
    X_test data
    Y_test data
    the category names (pulled from the Y_test dataframe)
    
    OUTPUT 
    excel metric files on how well each category performed, including 
    -accuracy
    -precision
    -recall
    -the F1 score
    
    the output files are later used in some visuals in the Flask app
       
    '''

    y_pred = model.predict(X_test)

        
    accuracy=accuracy_score(Y_test,y_pred)
    precision=precision_score(Y_test,y_pred,average='weighted',zero_division=1)
    recall=recall_score(Y_test,y_pred,average='weighted')
    f1score = f1_score(Y_test,y_pred,average='weighted')    
    print('\nscores:')
    temp ={  'model':model,
           #'sequence':sequence, 
           'Accurancy':accuracy,
                    'Precision':precision,
                    'Recall':recall,
                    'F1 Score':f1score}
    print(temp)
    return temp

# %%
#borrowing some code from my first project to save a little time and baking it into a definition
def get_top_n_important_features(df_train,model,n):
    feature_importances = list(zip(df_train.columns.tolist(), model.feature_importances_))

    df_feature_importances = pd.DataFrame(feature_importances, columns=['Feature', 'Model Weight'])
    filtered_features =df_feature_importances[df_feature_importances['Model Weight']>0] #screening out the lower rated features 
    sorted_features=filtered_features.sort_values(['Model Weight'],ascending=[False])
    top_n = sorted_features[:n] #looking at the top 10 

    top_n = top_n.reset_index()
    top_n = top_n.drop('index',axis=1)
    top_n.index += 1 #make the first number 1 since we're looking at a top 10.
    top_n[['Feature','Model Weight']]
    
    return top_n

# %%
#top features to pull out in descending rank order (using above def in each model)
topfeatures = 30

# %%
########################################################################################################
#train a generic Random Forest (default parameters) model to then look at model decay in future quarters 
#in other words, use the same model on successive quarters without retraining with new data. 
################################################################################################



dfout = prep_for_classifier(df)
X,y=get_X_y_data(dfout,sequence=sequences[0])
print('shapes')
print(dfout.shape,X.shape,y.shape)

### starting ML ##############
#split into train/test sets 
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.20,random_state=42)
#train a "no frills Random Forest Classifier"
rf = RandomForestClassifier(random_state=42)
rf.fit(X_train,y_train)

top_n_rf =get_top_n_important_features(X_train,model=rf,n=topfeatures)
# print('top 20 features using the no frills random forest classifier')
# print(top_n)
#evaluate_model(model=rf, X_test=X_test, Y_test=y_test)

####################################################################################################
#look at decay.. accuracy, precision, recall, F1 scores without training a new model with new data
####################################################################################################
l=[]

for j in range(len(sequences)):
    print('\n\n\nsequence:',j)
    #dfout,X,y = prep_for_classifier(df,sequence=sequences[j])
    X,y=get_X_y_data(dfout,sequence=sequences[j])
    print('shapes')
    print(dfout.shape,X.shape,y.shape)

    ### starting ML ##############
    #split into train/test sets 
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.20,random_state=42)
    try:
        evaluate_classifier_model(model=rf, X_test=X_test, Y_test=y_test)
        
        
    except Exception as e:
        print(e)
# Out:
# shapes
# (2480, 115) (496, 113) (496,)
#
#
#
# sequence: 0
# shapes
# (2480, 115) (496, 113) (496,)
#
# scores:
# {'model': RandomForestClassifier(random_state=42), 'Accurancy': 0.52, 'Precision': 0.52, 'Recall': 0.52, 'F1 Score': 0.52}
#
#
#
# sequence: 1
# shapes
# (2480, 115) (496, 113) (496,)
#
# scores:
# {'model': RandomForestClassifier(random_state=42), 'Accurancy': 0.48, 'Precision': 0.5229545454545454, 'Recall': 0.48, 'F1 Score': 0.4856362906463268}
#
#
#
# sequence: 2
# shapes
# (2480, 115) (496, 113) (496,)
#
# scores:
# {'model': RandomForestClassifier(random_state=42), 'Accurancy': 0.45, 'Precision': 0.4549671592775041, 'Recall': 0.45, 'F1 Score': 0.44696741854636585}
#
#
#
# sequence: 3
# shapes
# (2480, 115) (496, 113) (496,)
#
# scores:
# {'model': RandomForestClassifier(random_state=42), 'Accurancy': 0.45, 'Precision': 0.5428571428571428, 'Recall': 0.45, 'F1 Score': 0.47804878048780486}
#
#
#
# sequence: 4
# shapes
# (2480, 115) (496, 113) (496,)
#
# scores:
# {'model': RandomForestClassifier(random_state=42), 'Accurancy': 0.52, 'Precision': 0.5173333333333333, 'Recall': 0.52, 'F1 Score': 0.5153246753246753}

# %% [markdown]
# looking at the scores from the 4 sequences we can see that the accuracy dropped from 64.6 in the first sequence (quarter) to 49.0 in the last one. Precision dropped from 67.2 to 54.3.

# %%
#what if we try a different machine learning classifier? 

########################################################################################################
#train a generic Gradient Boosting Classifier (default parameters) model to then look at model decay in future quarters 
#in other words, use the same model on successive quarters without retraining with new data. 
################################################################################################



dfout = prep_for_classifier(df)
X,y=get_X_y_data(dfout,sequence=sequences[0])
print('shapes')
print(dfout.shape,X.shape,y.shape)

### starting ML ##############
#split into train/test sets 
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.20,random_state=42)

#train a "no frills GradientBoostingClassifier"
#rf = RandomForestClassifier(random_state=42)
#rf.fit(X_train,y_train)
gbc =GradientBoostingClassifier(random_state=42)
gbc.fit(X_train,y_train)
top_n_gbc =get_top_n_important_features(X_train,model=gbc,n=topfeatures)

#evaluate_model(model=rf, X_test=X_test, Y_test=y_test)

####################################################################################################
#look at decay.. accuracy, precision, recall, F1 scores without training a new model with new data
####################################################################################################
for j in range(len(sequences)):
    print('\n\n\nsequence:',j)
    #dfout,X,y = prep_for_classifier(df,sequence=sequences[j])
    X,y=get_X_y_data(dfout,sequence=sequences[j])
    print('shapes')
    print(dfout.shape,X.shape,y.shape)

    ### starting ML ##############
    #split into train/test sets 
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.20,random_state=42)
    nans = X_train.isna().sum()
    print('nans over zero?',nans[nans>0])
    try:
        evaluate_classifier_model(model=gbc, X_test=X_test, Y_test=y_test)
    except Exception as e:
        print(e)
# Out:
# shapes
# (2480, 115) (496, 113) (496,)
#
#
#
# sequence: 0
# shapes
# (2480, 115) (496, 113) (496,)
# nans over zero? Series([], dtype: int64)
#
# scores:
# {'model': GradientBoostingClassifier(random_state=42), 'Accurancy': 0.49, 'Precision': 0.4905769230769231, 'Recall': 0.49, 'F1 Score': 0.4898469846984698}
#
#
#
# sequence: 1
# shapes
# (2480, 115) (496, 113) (496,)
# nans over zero? Series([], dtype: int64)
#
# scores:
# {'model': GradientBoostingClassifier(random_state=42), 'Accurancy': 0.51, 'Precision': 0.5515555555555556, 'Recall': 0.51, 'F1 Score': 0.5158597125916994}
#
#
#
# sequence: 2
# shapes
# (2480, 115) (496, 113) (496,)
# nans over zero? Series([], dtype: int64)
#
# scores:
# {'model': GradientBoostingClassifier(random_state=42), 'Accurancy': 0.46, 'Precision': 0.46420202020202017, 'Recall': 0.46, 'F1 Score': 0.45913565426170466}
#
#
#
# sequence: 3
# shapes
# (2480, 115) (496, 113) (496,)
# nans over zero? Series([], dtype: int64)
#
# scores:
# {'model': GradientBoostingClassifier(random_state=42), 'Accurancy': 0.53, 'Precision': 0.6221848739495798, 'Recall': 0.53, 'F1 Score': 0.553968957871397}
#
#
#
# sequence: 4
# shapes
# (2480, 115) (496, 113) (496,)
# nans over zero? Series([], dtype: int64)
#
# scores:
# {'model': GradientBoostingClassifier(random_state=42), 'Accurancy': 0.53, 'Precision': 0.5289696969696969, 'Recall': 0.53, 'F1 Score': 0.5290081398854386}

# %% [markdown]
# The gradient booster classifier - using default values and no grid search - does a little better in the first sequence than the random forest with 66.6 accuracy and 68.8 precision. But, using the same model in successive quarters without retraining shows a steeper decay with the last sequence's accuracy at only 47.1 and precision of 52.3. Conclusion: we will need to retrain data for classifiers to attempt to avert potential score declines.

# %%
top_n_rf
# Out:
#                             Feature         Model Weight
# 1               investmentIncomeNet                 0.02
# 2           rolling62_adjustedclose                 0.02
# 3              debt_to_equity_ratio                 0.02
# 4             cashflowFromFinancing                 0.02
# 5             currentNetReceivables                 0.02
# 6               longTermInvestments                 0.02
# 7              changeInExchangeRate                 0.02
# 8            totalShareholderEquity                 0.02
# 9                 changeInInventory                 0.02
# 10                       debt_ratio                 0.02
# 11                    current_ratio                 0.02
# 12                        roe_ratio                 0.02
# 13           operating_margin_ratio                 0.01
# 14                         goodwill                 0.01
# 15                 retainedEarnings                 0.01
# 16                      investments                 0.01
# 17                 averageInventory                 0.01
# 18         inventory_turnover_ratio                 0.01
# 19                nonInterestIncome                 0.01
# 20     changeInOperatingLiabilities                 0.01
# 21        operating_cash_flow_ratio                 0.01
# 22          days_in_inventory_ratio                 0.01
# 23          interest_coverage_ratio                 0.01
# 24           cashflowFromInvestment                 0.01
# 25                    costOfRevenue                 0.01
# 26                operatingCashflow                 0.01
# 27          changeInOperatingAssets                 0.01
# 28               totalCurrentAssets                 0.01
# 29                  acid_test_ratio                 0.01
# 30  sellingGeneralAndAdministrative                 0.01

# %%
top_n_gbc
# Out:
#                               Feature         Model Weight
# 1             rolling62_adjustedclose                 0.07
# 2                          debt_ratio                 0.05
# 3                 investmentIncomeNet                 0.05
# 4                         investments                 0.04
# 5               gics_sector_Utilities                 0.04
# 6                changeInExchangeRate                 0.03
# 7                       current_ratio                 0.03
# 8              shortLongTermDebtTotal                 0.03
# 9             days_in_inventory_ratio                 0.03
# 10             propertyPlantEquipment                 0.03
# 11                  nonInterestIncome                 0.02
# 12             operating_margin_ratio                 0.02
# 13                  operatingCashflow                 0.02
# 14                        grossProfit                 0.02
# 15                      costOfRevenue                 0.02
# 16              cashflowFromFinancing                 0.02
# 17    proceedsFromOperatingActivities                 0.02
# 18            gics_sector_Industrials                 0.02
# 19                     dividendPayout                 0.02
# 20              otherNonCurrentAssets                 0.02
# 21             cashflowFromInvestment                 0.02
# 22            interest_coverage_ratio                 0.01
# 23                    interestExpense                 0.01
# 24     changeInCashAndCashEquivalents                 0.01
# 25                 gross_margin_ratio                 0.01
# 26            changeInOperatingAssets                 0.01
# 27                         cash_ratio                 0.01
# 28  proceedsFromIssuanceOfCommonStock                 0.01
# 29       changeInOperatingLiabilities                 0.01
# 30    sellingGeneralAndAdministrative                 0.01

# %%
#combined "best of both lists to use as feature subset"
topfilter1 = top_n_rf[top_n_rf['Model Weight']>0.01]
topfilter1 = topfilter1['Feature'].tolist()

type(top_n_gbc)

topfilter2 = top_n_gbc[top_n_gbc['Model Weight']>.02]
topfilter2 = topfilter2['Feature'].tolist()

combinedfilter = set(topfilter1).union(set(topfilter2))
combinedfilter = list(combinedfilter)

# %%
#correlations of features seem reasonably low. nothing more than in the .60s
corr = dfout[combinedfilter].corr()
corr.iloc[:,20:] #note - checked in 2 sets since otherwise middle ones don't show.
# Out:
#                                  changeInOperatingLiabilities  \
# investments                                             -0.04
# averageInventory                                         0.35
# sellingGeneralAndAdministrative                          0.04
# propertyPlantEquipment                                   0.01
# debt_to_equity_ratio                                    -0.00
# cashflowFromFinancing                                    0.08
# retainedEarnings                                        -0.07
# rolling62_adjustedclose                                  0.01
# changeInExchangeRate                                     0.09
# investmentIncomeNet                                     -0.12
# longTermInvestments                                     -0.10
# debt_ratio                                              -0.03
# shortLongTermDebtTotal                                  -0.26
# currentNetReceivables                                    0.13
# current_ratio                                            0.02
# gics_sector_Utilities                                   -0.00
# changeInInventory                                        0.11
# days_in_inventory_ratio                                  0.01
# goodwill                                                 0.04
# nonInterestIncome                                        0.04
# changeInOperatingLiabilities                             1.00
# inventory_turnover_ratio                                -0.00
# cashflowFromInvestment                                   0.22
# grossProfit                                              0.06
# totalCurrentAssets                                      -0.16
# operating_margin_ratio                                   0.01
# totalShareholderEquity                                  -0.05
# roe_ratio                                               -0.00
# changeInOperatingAssets                                  0.28
# costOfRevenue                                            0.03
# operating_cash_flow_ratio                                0.02
# interest_coverage_ratio                                  0.00
# acid_test_ratio                                          0.03
# operatingCashflow                                       -0.07
#
#                                  inventory_turnover_ratio  \
# investments                                          0.00
# averageInventory                                     0.00
# sellingGeneralAndAdministrative                     -0.01
# propertyPlantEquipment                              -0.01
# debt_to_equity_ratio                                -0.00
# cashflowFromFinancing                                0.00
# retainedEarnings                                    -0.00
# rolling62_adjustedclose                             -0.01
# changeInExchangeRate                                 0.00
# investmentIncomeNet                                 -0.00
# longTermInvestments                                 -0.00
# debt_ratio                                          -0.02
# shortLongTermDebtTotal                              -0.00
# currentNetReceivables                               -0.01
# current_ratio                                       -0.00
# gics_sector_Utilities                               -0.01
# changeInInventory                                   -0.00
# days_in_inventory_ratio                              0.00
# goodwill                                            -0.01
# nonInterestIncome                                   -0.01
# changeInOperatingLiabilities                        -0.00
# inventory_turnover_ratio                             1.00
# cashflowFromInvestment                               0.00
# grossProfit                                         -0.01
# totalCurrentAssets                                  -0.01
# operating_margin_ratio                               0.03
# totalShareholderEquity                               0.00
# roe_ratio                                           -0.00
# changeInOperatingAssets                             -0.00
# costOfRevenue                                       -0.01
# operating_cash_flow_ratio                           -0.00
# interest_coverage_ratio                             -0.00
# acid_test_ratio                                     -0.00
# operatingCashflow                                   -0.00
#
#                                  cashflowFromInvestment          grossProfit  \
# investments                                        0.19                 0.06
# averageInventory                                   0.16                -0.02
# sellingGeneralAndAdministrative                   -0.18                 0.45
# propertyPlantEquipment                            -0.22                 0.53
# debt_to_equity_ratio                               0.00                -0.01
# cashflowFromFinancing                             -0.06                -0.17
# retainedEarnings                                  -0.11                 0.66
# rolling62_adjustedclose                            0.00                 0.01
# changeInExchangeRate                               0.15                -0.04
# investmentIncomeNet                               -0.18                 0.19
# longTermInvestments                                0.15                 0.08
# debt_ratio                                        -0.01                -0.03
# shortLongTermDebtTotal                            -0.06                 0.25
# currentNetReceivables                             -0.17                 0.50
# current_ratio                                     -0.07                -0.03
# gics_sector_Utilities                             -0.04                -0.03
# changeInInventory                                  0.32                -0.00
# days_in_inventory_ratio                            0.04                -0.01
# goodwill                                          -0.08                 0.41
# nonInterestIncome                                 -0.15                 0.48
# changeInOperatingLiabilities                       0.22                 0.06
# inventory_turnover_ratio                           0.00                -0.01
# cashflowFromInvestment                             1.00                -0.18
# grossProfit                                       -0.18                 1.00
# totalCurrentAssets                                -0.13                 0.42
# operating_margin_ratio                             0.00                -0.00
# totalShareholderEquity                            -0.12                 0.63
# roe_ratio                                         -0.00                 0.01
# changeInOperatingAssets                            0.34                 0.07
# costOfRevenue                                     -0.11                 0.17
# operating_cash_flow_ratio                         -0.01                -0.02
# interest_coverage_ratio                            0.01                -0.01
# acid_test_ratio                                   -0.03                -0.05
# operatingCashflow                                 -0.46                 0.38
#
#                                   totalCurrentAssets  operating_margin_ratio  \
# investments                                     0.54                   -0.01
# averageInventory                               -0.65                   -0.00
# sellingGeneralAndAdministrative                 0.34                   -0.00
# propertyPlantEquipment                          0.23                   -0.00
# debt_to_equity_ratio                            0.01                    0.01
# cashflowFromFinancing                          -0.28                    0.00
# retainedEarnings                                0.72                   -0.00
# rolling62_adjustedclose                        -0.02                   -0.00
# changeInExchangeRate                           -0.23                   -0.02
# investmentIncomeNet                             0.56                    0.00
# longTermInvestments                             0.67                   -0.01
# debt_ratio                                      0.08                    0.02
# shortLongTermDebtTotal                          0.67                   -0.00
# currentNetReceivables                           0.28                    0.03
# current_ratio                                   0.21                   -0.00
# gics_sector_Utilities                          -0.06                   -0.00
# changeInInventory                               0.16                    0.00
# days_in_inventory_ratio                        -0.07                    0.05
# goodwill                                        0.44                   -0.01
# nonInterestIncome                               0.32                   -0.01
# changeInOperatingLiabilities                   -0.16                    0.01
# inventory_turnover_ratio                       -0.01                    0.03
# cashflowFromInvestment                         -0.13                    0.00
# grossProfit                                     0.42                   -0.00
# totalCurrentAssets                              1.00                   -0.01
# operating_margin_ratio                         -0.01                    1.00
# totalShareholderEquity                          0.79                   -0.01
# roe_ratio                                       0.01                   -0.00
# changeInOperatingAssets                         0.25                    0.00
# costOfRevenue                                   0.31                   -0.00
# operating_cash_flow_ratio                      -0.01                    0.00
# interest_coverage_ratio                        -0.01                   -0.00
# acid_test_ratio                                 0.08                    0.05
# operatingCashflow                               0.30                   -0.00
#
#                                  totalShareholderEquity            roe_ratio  \
# investments                                        0.48                 0.00
# averageInventory                                  -0.39                 0.00
# sellingGeneralAndAdministrative                    0.41                 0.01
# propertyPlantEquipment                             0.47                 0.01
# debt_to_equity_ratio                               0.00                 0.24
# cashflowFromFinancing                             -0.26                -0.01
# retainedEarnings                                   0.87                 0.01
# rolling62_adjustedclose                           -0.04                 0.02
# changeInExchangeRate                              -0.08                -0.00
# investmentIncomeNet                                0.36                 0.00
# longTermInvestments                                0.53                 0.00
# debt_ratio                                        -0.10                -0.02
# shortLongTermDebtTotal                             0.57                 0.01
# currentNetReceivables                              0.39                 0.01
# current_ratio                                      0.03                 0.00
# gics_sector_Utilities                             -0.02                -0.00
# changeInInventory                                  0.12                 0.00
# days_in_inventory_ratio                           -0.03                 0.00
# goodwill                                           0.60                 0.00
# nonInterestIncome                                  0.41                 0.02
# changeInOperatingLiabilities                      -0.05                -0.00
# inventory_turnover_ratio                           0.00                -0.00
# cashflowFromInvestment                            -0.12                -0.00
# grossProfit                                        0.63                 0.01
# totalCurrentAssets                                 0.79                 0.01
# operating_margin_ratio                            -0.01                -0.00
# totalShareholderEquity                             1.00                 0.01
# roe_ratio                                          0.01                 1.00
# changeInOperatingAssets                            0.18                 0.00
# costOfRevenue                                      0.29                 0.01
# operating_cash_flow_ratio                         -0.01                -0.00
# interest_coverage_ratio                           -0.01                 0.00
# acid_test_ratio                                    0.02                -0.00
# operatingCashflow                                  0.37                 0.01
#
#                                  changeInOperatingAssets        costOfRevenue  \
# investments                                         0.05                 0.12
# averageInventory                                   -0.32                -0.06
# sellingGeneralAndAdministrative                     0.06                 0.64
# propertyPlantEquipment                              0.05                 0.30
# debt_to_equity_ratio                                0.00                -0.00
# cashflowFromFinancing                               0.29                -0.13
# retainedEarnings                                    0.17                 0.24
# rolling62_adjustedclose                            -0.00                -0.01
# changeInExchangeRate                               -0.18                -0.06
# investmentIncomeNet                                 0.30                 0.18
# longTermInvestments                                 0.24                 0.14
# debt_ratio                                          0.02                 0.08
# shortLongTermDebtTotal                              0.08                 0.21
# currentNetReceivables                               0.06                 0.52
# current_ratio                                       0.00                 0.00
# gics_sector_Utilities                              -0.01                -0.09
# changeInInventory                                   0.80                 0.03
# days_in_inventory_ratio                            -0.01                 0.01
# goodwill                                            0.09                 0.31
# nonInterestIncome                                   0.04                 0.64
# changeInOperatingLiabilities                        0.28                 0.03
# inventory_turnover_ratio                           -0.00                -0.01
# cashflowFromInvestment                              0.34                -0.11
# grossProfit                                         0.07                 0.17
# totalCurrentAssets                                  0.25                 0.31
# operating_margin_ratio                              0.00                -0.00
# totalShareholderEquity                              0.18                 0.29
# roe_ratio                                           0.00                 0.01
# changeInOperatingAssets                             1.00                 0.06
# costOfRevenue                                       0.06                 1.00
# operating_cash_flow_ratio                          -0.01                -0.01
# interest_coverage_ratio                            -0.00                -0.02
# acid_test_ratio                                     0.01                 0.03
# operatingCashflow                                  -0.56                 0.22
#
#                                  operating_cash_flow_ratio  \
# investments                                           0.01
# averageInventory                                      0.00
# sellingGeneralAndAdministrative                      -0.02
# propertyPlantEquipment                               -0.02
# debt_to_equity_ratio                                 -0.00
# cashflowFromFinancing                                 0.01
# retainedEarnings                                     -0.01
# rolling62_adjustedclose                              -0.01
# changeInExchangeRate                                  0.00
# investmentIncomeNet                                  -0.00
# longTermInvestments                                   0.00
# debt_ratio                                           -0.00
# shortLongTermDebtTotal                               -0.01
# currentNetReceivables                                -0.03
# current_ratio                                         0.46
# gics_sector_Utilities                                -0.02
# changeInInventory                                    -0.00
# days_in_inventory_ratio                               0.01
# goodwill                                             -0.02
# nonInterestIncome                                    -0.02
# changeInOperatingLiabilities                          0.02
# inventory_turnover_ratio                             -0.00
# cashflowFromInvestment                               -0.01
# grossProfit                                          -0.02
# totalCurrentAssets                                   -0.01
# operating_margin_ratio                                0.00
# totalShareholderEquity                               -0.01
# roe_ratio                                            -0.00
# changeInOperatingAssets                              -0.01
# costOfRevenue                                        -0.01
# operating_cash_flow_ratio                             1.00
# interest_coverage_ratio                               0.00
# acid_test_ratio                                       0.19
# operatingCashflow                                     0.00
#
#                                  interest_coverage_ratio      acid_test_ratio  \
# investments                                        -0.01                 0.08
# averageInventory                                    0.00                -0.07
# sellingGeneralAndAdministrative                    -0.02                -0.00
# propertyPlantEquipment                             -0.02                -0.03
# debt_to_equity_ratio                               -0.00                 0.01
# cashflowFromFinancing                               0.00                 0.02
# retainedEarnings                                   -0.01                 0.03
# rolling62_adjustedclose                            -0.02                -0.02
# changeInExchangeRate                                0.00                -0.02
# investmentIncomeNet                                -0.01                -0.02
# longTermInvestments                                -0.01                 0.10
# debt_ratio                                         -0.07                 0.08
# shortLongTermDebtTotal                             -0.02                 0.01
# currentNetReceivables                              -0.01                 0.02
# current_ratio                                      -0.00                 0.46
# gics_sector_Utilities                              -0.01                -0.02
# changeInInventory                                  -0.00                 0.01
# days_in_inventory_ratio                             0.00                -0.03
# goodwill                                           -0.02                -0.01
# nonInterestIncome                                  -0.01                -0.01
# changeInOperatingLiabilities                        0.00                 0.03
# inventory_turnover_ratio                           -0.00                -0.00
# cashflowFromInvestment                              0.01                -0.03
# grossProfit                                        -0.01                -0.05
# totalCurrentAssets                                 -0.01                 0.08
# operating_margin_ratio                             -0.00                 0.05
# totalShareholderEquity                             -0.01                 0.02
# roe_ratio                                           0.00                -0.00
# changeInOperatingAssets                            -0.00                 0.01
# costOfRevenue                                      -0.02                 0.03
# operating_cash_flow_ratio                           0.00                 0.19
# interest_coverage_ratio                             1.00                -0.01
# acid_test_ratio                                    -0.01                 1.00
# operatingCashflow                                  -0.01                 0.01
#
#                                    operatingCashflow
# investments                                     0.15
# averageInventory                               -0.04
# sellingGeneralAndAdministrative                 0.31
# propertyPlantEquipment                          0.30
# debt_to_equity_ratio                            0.00
# cashflowFromFinancing                          -0.49
# retainedEarnings                                0.33
# rolling62_adjustedclose                         0.00
# changeInExchangeRate                            0.01
# investmentIncomeNet                             0.16
# longTermInvestments                             0.08
# debt_ratio                                     -0.02
# shortLongTermDebtTotal                          0.23
# currentNetReceivables                           0.38
# current_ratio                                   0.02
# gics_sector_Utilities                          -0.03
# changeInInventory                              -0.57
# days_in_inventory_ratio                        -0.01
# goodwill                                        0.23
# nonInterestIncome                               0.32
# changeInOperatingLiabilities                   -0.07
# inventory_turnover_ratio                       -0.00
# cashflowFromInvestment                         -0.46
# grossProfit                                     0.38
# totalCurrentAssets                              0.30
# operating_margin_ratio                         -0.00
# totalShareholderEquity                          0.37
# roe_ratio                                       0.01
# changeInOperatingAssets                        -0.56
# costOfRevenue                                   0.22
# operating_cash_flow_ratio                       0.00
# interest_coverage_ratio                        -0.01
# acid_test_ratio                                 0.01
# operatingCashflow                               1.00

# %%
########################################################################################################
#train a generic Random Forest with the subset of features (still using default parameters)  to then look at model decay in future quarters 
#in other words, use the same model on successive quarters without retraining with new data. 
################################################################################################


dfout = prep_for_classifier(df)
X,y=get_X_y_data(dfout,sequence=sequences[0])
X = X[combinedfilter]
print('shapes')
print(dfout.shape,X.shape,y.shape)

### starting ML ##############
#split into train/test sets 
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.20,random_state=42)
#train a "no frills Random Forest Classifier"
rf = RandomForestClassifier(random_state=42)
rf.fit(X_train,y_train)



top_n_rf =get_top_n_important_features(X_train,model=rf,n=10)
# print('top 20 features using the no frills random forest classifier')
# print(top_n)
#evaluate_model(model=rf, X_test=X_test, Y_test=y_test)

####################################################################################################
#look at decay.. accuracy, precision, recall, F1 scores without training a new model with new data
####################################################################################################
l=[]

for j in range(len(sequences)):
    print('\n\n\nsequence:',j)
    #dfout,X,y = prep_for_classifier(df,sequence=sequences[j])
    X,y=get_X_y_data(dfout,sequence=sequences[j])
    X = X[combinedfilter]
    print('shapes')
    print(dfout.shape,X.shape,y.shape)

    ### starting ML ##############
    #split into train/test sets 
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.20,random_state=42)
    try:
        evaluate_classifier_model(model=rf, X_test=X_test, Y_test=y_test)
        
        
    except Exception as e:
        print(e)
# Out:
# shapes
# (2480, 115) (496, 34) (496,)
#
#
#
# sequence: 0
# shapes
# (2480, 115) (496, 34) (496,)
#
# scores:
# {'model': RandomForestClassifier(random_state=42), 'Accurancy': 0.49, 'Precision': 0.48979166666666674, 'Recall': 0.49, 'F1 Score': 0.48984686217595835}
#
#
#
# sequence: 1
# shapes
# (2480, 115) (496, 34) (496,)
#
# scores:
# {'model': RandomForestClassifier(random_state=42), 'Accurancy': 0.47, 'Precision': 0.5197436957420422, 'Recall': 0.47, 'F1 Score': 0.4733420078070263}
#
#
#
# sequence: 2
# shapes
# (2480, 115) (496, 34) (496,)
#
# scores:
# {'model': RandomForestClassifier(random_state=42), 'Accurancy': 0.46, 'Precision': 0.46672672672672677, 'Recall': 0.46, 'F1 Score': 0.45127272727272727}
#
#
#
# sequence: 3
# shapes
# (2480, 115) (496, 34) (496,)
#
# scores:
# {'model': RandomForestClassifier(random_state=42), 'Accurancy': 0.51, 'Precision': 0.5686316659776768, 'Recall': 0.51, 'F1 Score': 0.5318464431906185}
#
#
#
# sequence: 4
# shapes
# (2480, 115) (496, 34) (496,)
#
# scores:
# {'model': RandomForestClassifier(random_state=42), 'Accurancy': 0.57, 'Precision': 0.5692121212121212, 'Recall': 0.57, 'F1 Score': 0.5690925535122098}

# %%
########################################################################################################
#train a generic Gradient Boosting Classifier with the subset of features (still using default parameters)  to then look at model decay in future quarters 
#in other words, use the same model on successive quarters without retraining with new data. 
################################################################################################

dfout = prep_for_classifier(df)
X,y=get_X_y_data(dfout,sequence=sequences[0])
X = X[combinedfilter]
print('shapes')
print(dfout.shape,X.shape,y.shape)

### starting ML ##############
#split into train/test sets 
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.20,random_state=42)
#train a "no frills Random Forest Classifier"

gbc =GradientBoostingClassifier(random_state=42)
gbc.fit(X_train,y_train)
top_n_gbc =get_top_n_important_features(X_train,model=gbc,n=20)

# print('top 20 features using the no frills random forest classifier')
# print(top_n)
#evaluate_model(model=rf, X_test=X_test, Y_test=y_test)

####################################################################################################
#look at decay.. accuracy, precision, recall, F1 scores without training a new model with new data
####################################################################################################
l=[]

for j in range(len(sequences)):
    print('\n\n\nsequence:',j)
    #dfout,X,y = prep_for_classifier(df,sequence=sequences[j])
    X,y=get_X_y_data(dfout,sequence=sequences[j])
    X = X[combinedfilter]
    print('shapes')
    print(dfout.shape,X.shape,y.shape)

    ### starting ML ##############
    #split into train/test sets 
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.20,random_state=42)
    try:
        evaluate_classifier_model(model=rf, X_test=X_test, Y_test=y_test)
        
        
    except Exception as e:
        print(e)
# Out:
# shapes
# (2480, 115) (496, 34) (496,)
#
#
#
# sequence: 0
# shapes
# (2480, 115) (496, 34) (496,)
#
# scores:
# {'model': RandomForestClassifier(random_state=42), 'Accurancy': 0.49, 'Precision': 0.48979166666666674, 'Recall': 0.49, 'F1 Score': 0.48984686217595835}
#
#
#
# sequence: 1
# shapes
# (2480, 115) (496, 34) (496,)
#
# scores:
# {'model': RandomForestClassifier(random_state=42), 'Accurancy': 0.47, 'Precision': 0.5197436957420422, 'Recall': 0.47, 'F1 Score': 0.4733420078070263}
#
#
#
# sequence: 2
# shapes
# (2480, 115) (496, 34) (496,)
#
# scores:
# {'model': RandomForestClassifier(random_state=42), 'Accurancy': 0.46, 'Precision': 0.46672672672672677, 'Recall': 0.46, 'F1 Score': 0.45127272727272727}
#
#
#
# sequence: 3
# shapes
# (2480, 115) (496, 34) (496,)
#
# scores:
# {'model': RandomForestClassifier(random_state=42), 'Accurancy': 0.51, 'Precision': 0.5686316659776768, 'Recall': 0.51, 'F1 Score': 0.5318464431906185}
#
#
#
# sequence: 4
# shapes
# (2480, 115) (496, 34) (496,)
#
# scores:
# {'model': RandomForestClassifier(random_state=42), 'Accurancy': 0.57, 'Precision': 0.5692121212121212, 'Recall': 0.57, 'F1 Score': 0.5690925535122098}

# %%
########################################################################################################
#now retrain a generic Random Forest with the subset of features (still using default parameters) 
#for each quarter  
################################################################################################


dfout = prep_for_classifier(df)
X,y=get_X_y_data(dfout,sequence=sequences[0])
X = X[combinedfilter]
print('shapes')
print(dfout.shape,X.shape,y.shape)


####################################################################################################
#look at decay.. accuracy, precision, recall, F1 scores without training a new model with new data
####################################################################################################
l=[]

for j in range(len(sequences)):
    print('\n\n\nsequence:',j)
    #dfout,X,y = prep_for_classifier(df,sequence=sequences[j])
    X,y=get_X_y_data(dfout,sequence=sequences[j])
    X = X[combinedfilter]
    rf = RandomForestClassifier(random_state=42)
    rf.fit(X_train,y_train)
    print('shapes')
    print(dfout.shape,X.shape,y.shape)

    ### starting ML ##############
    #split into train/test sets 
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.20,random_state=42)
    try:
        evaluate_classifier_model(model=rf, X_test=X_test, Y_test=y_test)
        
        
    except Exception as e:
        print(e)
# Out:
# shapes
# (2480, 115) (496, 34) (496,)
#
#
#
# sequence: 0
# shapes
# (2480, 115) (496, 34) (496,)
#
# scores:
# {'model': RandomForestClassifier(random_state=42), 'Accurancy': 0.52, 'Precision': 0.5187644787644787, 'Recall': 0.52, 'F1 Score': 0.5117747858017136}
#
#
#
# sequence: 1
# shapes
# (2480, 115) (496, 34) (496,)
#
# scores:
# {'model': RandomForestClassifier(random_state=42), 'Accurancy': 0.47, 'Precision': 0.5197436957420422, 'Recall': 0.47, 'F1 Score': 0.4733420078070263}
#
#
#
# sequence: 2
# shapes
# (2480, 115) (496, 34) (496,)
#
# scores:
# {'model': RandomForestClassifier(random_state=42), 'Accurancy': 0.61, 'Precision': 0.6271491228070175, 'Recall': 0.61, 'F1 Score': 0.581598427775958}
#
#
#
# sequence: 3
# shapes
# (2480, 115) (496, 34) (496,)
#
# scores:
# {'model': RandomForestClassifier(random_state=42), 'Accurancy': 0.52, 'Precision': 0.5822988505747126, 'Recall': 0.52, 'F1 Score': 0.5421538461538461}
#
#
#
# sequence: 4
# shapes
# (2480, 115) (496, 34) (496,)
#
# scores:
# {'model': RandomForestClassifier(random_state=42), 'Accurancy': 0.56, 'Precision': 0.6426086956521739, 'Recall': 0.56, 'F1 Score': 0.4639682539682539}

# %%
########################################################################################################
#retrain a generic Gradient Boosting Classifier with the subset of features (still using default parameters) 
#each quarter  
################################################################################################


# dfout = prep_for_classifier(df)
# X,y=get_X_y_data(dfout,sequence=sequences[0])
# X = X[combinedfilter]
print('shapes')
print(dfout.shape,X.shape,y.shape)


####################################################################################################
#look at decay.. accuracy, precision, recall, F1 scores without training a new model with new data
####################################################################################################
l=[]

for j in range(len(sequences)):
    print('\n\n\nsequence:',j)
    #dfout,X,y = prep_for_classifier(df,sequence=sequences[j])
    X,y=get_X_y_data(dfout,sequence=sequences[j])
    X = X[combinedfilter]
    print('shapes')
    print(dfout.shape,X.shape,y.shape)

    ### starting ML ##############
    #split into train/test sets 
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.20,random_state=42)
    gbc =GradientBoostingClassifier(random_state=42)
    gbc.fit(X_train,y_train)
    top_n_gbc =get_top_n_important_features(X_train,model=gbc,n=20)
    try:
        evaluate_classifier_model(model=gbc, X_test=X_test, Y_test=y_test)
        
        
    except Exception as e:
        print(e)
# Out:
# shapes
# (2480, 115) (496, 34) (496,)
#
#
#
# sequence: 0
# shapes
# (2480, 115) (496, 34) (496,)
#
# scores:
# {'model': GradientBoostingClassifier(random_state=42), 'Accurancy': 0.52, 'Precision': 0.52, 'Recall': 0.52, 'F1 Score': 0.52}
#
#
#
# sequence: 1
# shapes
# (2480, 115) (496, 34) (496,)
#
# scores:
# {'model': GradientBoostingClassifier(random_state=42), 'Accurancy': 0.6, 'Precision': 0.5847619047619047, 'Recall': 0.6, 'F1 Score': 0.5885918003565063}
#
#
#
# sequence: 2
# shapes
# (2480, 115) (496, 34) (496,)
#
# scores:
# {'model': GradientBoostingClassifier(random_state=42), 'Accurancy': 0.55, 'Precision': 0.5518, 'Recall': 0.55, 'F1 Score': 0.5504053648283456}
#
#
#
# sequence: 3
# shapes
# (2480, 115) (496, 34) (496,)
#
# scores:
# {'model': GradientBoostingClassifier(random_state=42), 'Accurancy': 0.75, 'Precision': 0.7267904509283819, 'Recall': 0.75, 'F1 Score': 0.7160607455131155}
#
#
#
# sequence: 4
# shapes
# (2480, 115) (496, 34) (496,)
#
# scores:
# {'model': GradientBoostingClassifier(random_state=42), 'Accurancy': 0.67, 'Precision': 0.6703875968992247, 'Recall': 0.67, 'F1 Score': 0.6685028732735154}

# %%
# sequence: 3
# shapes
# (1984, 115) (496, 32) (496,)

# scores:
# {'model': RandomForestClassifier(random_state=42), 'Accurancy': 0.48,
#  'Precision': 0.5684615384615385, 'Recall': 0.48, 'F1 Score': 0.5064855687606112}

# %% [markdown]
# # Adding regression models to see if we can predict amount of change

# %%
def prep_for_regressor(df):
    df = df[df['sequence']!=5]

    #keeping return in ML would mean data leakage. 
    df = df.drop('return',axis=1) #we will use this later. But we would not know this in advance. 
    #pulling out sequence separately. we do not want to normalize this particular column. 
    seqvar = pd.DataFrame(df['sequence'])
    df = df.drop('sequence',axis=1)
    df=df.drop('better_than_spy',axis=1)
    
    #borrowing some code from project 1 
    num_vars = df.select_dtypes(include=['float','int']).columns
    cat_vars = df.select_dtypes(include=['object']).columns
    dfnum = df[num_vars]
    booleanvars = [col for col in dfnum.columns if set(dfnum[col].unique()).issubset({0,1})]
    #print(len(booleanvars))
    nonbooleanvars = list(set(num_vars)-set(booleanvars))
    

    #create dummy variables for the categorical variable set then drop the original categorical non numerical columns
    l = [df[cat_vars]]
    for i in range(len(cat_vars)):
        temp = cat_vars[i]
        catout = pd.get_dummies(df[temp],prefix=temp,prefix_sep='_',dummy_na=True,drop_first=True)
        l.append(catout)
    dfcat=pd.concat(l,axis=1)
    dfcat=dfcat.drop(columns=cat_vars,axis=0)
    #print(df.shape)
    #print(dfcat.shape) #expecting an increase due to adding dummies. 
    cat_cols = dfcat.columns.tolist()
    for i in range(len(cat_cols)):
        dfcat[cat_cols[i]] = dfcat[cat_cols[i]].astype(int)
    
    df_bool = df[booleanvars]
    df_nonbool = df[nonbooleanvars]
    df_nonbool = (df_nonbool-df_nonbool.mean())/df_nonbool.std()
    new_df = pd.concat([dfcat,seqvar,df_nonbool,df_bool],axis=1)

    return new_df
def get_X_y_data_regressor(df,sequence):
    #print(df.shape)
    
    df = df[df['sequence']==sequence]
    #print(df.shape)
    df = df.drop('sequence',axis=1)
           
    X = df #.iloc[:,:-1]
    X = X.drop('next_rolling62_adjustedclose',axis=1)

    #X.to_excel('X.xlsx')    
    #print(X.columns.tolist())
    y = df['next_rolling62_adjustedclose'].values
    y=df['next_rolling62_adjustedclose'].values
    #y=y['better_than_spy'].values
    return X,y

# %%
def evaluate_regressor_model(model, X_test, y_test): #, category_names=None):
    '''INPUT
    the machine learning model we built earlier
    X_test data
    Y_test data
    the category names (pulled from the Y_test dataframe)
    
    OUTPUT 
    excel metric files on how well each category performed, including 
    -accuracy
    -precision
    -recall
    -the F1 score
    
    the output files are later used in some visuals in the Flask app
       
    '''

    y_pred = model.predict(X_test)

        
    #source:https://stackoverflow.com/questions/50789508/random-forest-regression-how-do-i-analyse-its-performance-python-sklearn
    print('Mean Absolute Error (MAE):', metrics.mean_absolute_error(y_test, y_pred))
    print('Mean Squared Error (MSE):', metrics.mean_squared_error(y_test, y_pred))
    print('Root Mean Squared Error (RMSE):', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
    mape = np.mean(np.abs((y_test - y_pred) / np.abs(y_test)))
    print('Mean Absolute Percentage Error (MAPE):', round(mape * 100, 2))
    print('Accuracy:', round(100*(1 - mape), 2))
    print('Score:',r2_score(y_test, y_pred))
    #print(temp)
    #return temp

# %%
rdf = prep_for_regressor(df)
rdf.head()
# Out:
#         gics_sector_Consumer Discretionary  gics_sector_Consumer Staples  \
# ticker
# MMM                                      0                             0
# MMM                                      0                             0
# MMM                                      0                             0
# MMM                                      0                             0
# MMM                                      0                             0
#
#         gics_sector_Energy  gics_sector_Financials  gics_sector_Health Care  \
# ticker
# MMM                      0                       0                        0
# MMM                      0                       0                        0
# MMM                      0                       0                        0
# MMM                      0                       0                        0
# MMM                      0                       0                        0
#
#         gics_sector_Industrials  gics_sector_Information Technology  \
# ticker
# MMM                           1                                   0
# MMM                           1                                   0
# MMM                           1                                   0
# MMM                           1                                   0
# MMM                           1                                   0
#
#         gics_sector_Materials  gics_sector_Real Estate  gics_sector_Utilities  \
# ticker
# MMM                         0                        0                      0
# MMM                         0                        0                      0
# MMM                         0                        0                      0
# MMM                         0                        0                      0
# MMM                         0                        0                      0
#
#         ...  paymentsForRepurchaseOfPreferredStock  dividendPayoutCommonStock  \
# ticker  ...
# MMM     ...                                  -0.05                       0.79
# MMM     ...                                  -0.05                       0.80
# MMM     ...                                  -0.05                       0.75
# MMM     ...                                  -0.05                       0.76
# MMM     ...                                  -0.05                       0.76
#
#         paymentsForRepurchaseOfEquity  paymentsForOperatingActivities  \
# ticker
# MMM                             -0.30                           -0.06
# MMM                             -0.19                           -0.06
# MMM                              0.08                           -0.06
# MMM                             -0.28                           -0.06
# MMM                             -0.30                           -0.06
#
#               costOfRevenue  capitalExpenditures  interest_coverage_ratio  \
# ticker
# MMM                   -0.00                -0.12                    -0.04
# MMM                   -0.03                -0.08                    -0.04
# MMM                   -0.05                -0.03                    -0.04
# MMM                   -0.04                -0.05                    -0.04
# MMM                   -0.12                -0.12                    -0.05
#
#          otherCurrentAssets    operatingCashflow  costofGoodsAndServicesSold
# ticker
# MMM                   -0.10                -0.04                        0.10
# MMM                   -0.10                 0.04                        0.06
# MMM                   -0.10                 0.12                        0.05
# MMM                   -0.10                -0.01                        0.05
# MMM                   -0.10                 0.04                        0.05
#
# [5 rows x 115 columns]

# %%
rdf.columns.tolist()
# Out:
# ['gics_sector_Consumer Discretionary',
#  'gics_sector_Consumer Staples',
#  'gics_sector_Energy',
#  'gics_sector_Financials',
#  'gics_sector_Health Care',
#  'gics_sector_Industrials',
#  'gics_sector_Information Technology',
#  'gics_sector_Materials',
#  'gics_sector_Real Estate',
#  'gics_sector_Utilities',
#  'gics_sector_nan',
#  'sequence',
#  'operatingExpenses',
#  'investments',
#  'totalAssets',
#  'sellingGeneralAndAdministrative',
#  'intangibleAssets',
#  'comprehensiveIncomeNetOfTax',
#  'accumulatedDepreciationAmortizationPPE',
#  'totalRevenue',
#  'debt_to_equity_ratio',
#  'cashflowFromFinancing',
#  'retainedEarnings',
#  'longTermDebtNoncurrent',
#  'intangibleAssetsExcludingGoodwill',
#  'changeInCashAndCashEquivalents',
#  'changeInExchangeRate',
#  'commonStock',
#  'investmentIncomeNet',
#  'otherNonCurrentAssets',
#  'inventory',
#  'debt_ratio',
#  'current_ratio',
#  'currentNetReceivables',
#  'shortTermDebt',
#  'incomeTaxExpense',
#  'changeInInventory',
#  'grossProfit',
#  'cashflowFromInvestment',
#  'changeInOperatingLiabilities',
#  'otherNonCurrentLiabilities',
#  'proceedsFromOperatingActivities',
#  'totalCurrentAssets',
#  'ebitda',
#  'cashAndCashEquivalentsAtCarryingValue',
#  'asset_turnover_ratio',
#  'depreciationAndAmortization',
#  'netIncomeFromContinuingOperations',
#  'totalShareholderEquity',
#  'profitLoss',
#  'roa_ratio',
#  'roe_ratio',
#  'netIncome',
#  'changeInOperatingAssets',
#  'interestExpense',
#  'proceedsFromSaleOfTreasuryStock',
#  'commonStockSharesOutstanding',
#  'operating_cash_flow_ratio',
#  'acid_test_ratio',
#  'totalCurrentLiabilities',
#  'totalNonCurrentLiabilities',
#  'interestAndDebtExpense',
#  'proceedsFromRepaymentsOfShortTermDebt',
#  'averageInventory',
#  'dividendPayoutPreferredStock',
#  'otherNonOperatingIncome',
#  'operatingIncome',
#  'propertyPlantEquipment',
#  'gross_margin_ratio',
#  'changeInReceivables',
#  'totalNonCurrentAssets',
#  'paymentsForRepurchaseOfCommonStock',
#  'otherCurrentLiabilities',
#  'depreciation',
#  'longTermDebt',
#  'depreciationDepletionAndAmortization',
#  'researchAndDevelopment',
#  'proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet',
#  'proceedsFromIssuanceOfPreferredStock',
#  'rolling62_adjustedclose',
#  'ebit',
#  'cash_ratio',
#  'capitalLeaseObligations',
#  'currentAccountsPayable',
#  'next_rolling62_adjustedclose',
#  'shortTermInvestments',
#  'longTermInvestments',
#  'currentDebt',
#  'shortLongTermDebtTotal',
#  'interestIncome',
#  'dividendPayout',
#  'totalLiabilities',
#  'cashAndShortTermInvestments',
#  'treasuryStock',
#  'proceedsFromRepurchaseOfEquity',
#  'days_in_inventory_ratio',
#  'goodwill',
#  'currentLongTermDebt',
#  'nonInterestIncome',
#  'inventory_turnover_ratio',
#  'netInterestIncome',
#  'incomeBeforeTax',
#  'proceedsFromIssuanceOfCommonStock',
#  'operating_margin_ratio',
#  'deferredRevenue',
#  'paymentsForRepurchaseOfPreferredStock',
#  'dividendPayoutCommonStock',
#  'paymentsForRepurchaseOfEquity',
#  'paymentsForOperatingActivities',
#  'costOfRevenue',
#  'capitalExpenditures',
#  'interest_coverage_ratio',
#  'otherCurrentAssets',
#  'operatingCashflow',
#  'costofGoodsAndServicesSold']

# %%
for i in range(len(combinedfilter)):
    #xplot = rdf[combinedfilter[i]]
    plt.figure() 
    sns.scatterplot(data=rdf, x=str(combinedfilter[i]), y='next_rolling62_adjustedclose') #, hue="time")
# Out:
# /tmp/ipykernel_42358/1525834725.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()

# %%
########################################################################################################
#train a generic Random Forest Regressor (default parameters) model to then look at model decay in future quarters 
#in other words, use the same model on successive quarters without retraining with new data. 
################################################################################################


dfout = prep_for_regressor(df)
X,y=get_X_y_data_regressor(dfout,sequence=sequences[0])
print('shapes')
print(dfout.shape,X.shape,y.shape)

### starting ML ##############
#split into train/test sets 
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.20,random_state=42)
#train a "no frills Random Forest Classifier"
rfr = RandomForestRegressor(random_state=42)
rfr.fit(X_train,y_train)

top_n_rfr =get_top_n_important_features(X_train,model=rf,n=topfeatures)
print('how the model ranks the same feature subset')
print(top_n_rfr)
#evaluate_model(model=rf, X_test=X_test, Y_test=y_test)

####################################################################################################
#look at decay.. accuracy, precision, recall, F1 scores without training a new model with new data
####################################################################################################
l=[]

for j in range(len(sequences)):
    print('\n\n\nsequence:',j)
    #dfout,X,y = prep_for_classifier(df,sequence=sequences[j])
    X,y=get_X_y_data_regressor(dfout,sequence=sequences[j])
    print('shapes')
    print(dfout.shape,X.shape,y.shape)

    ### starting ML ##############
    #split into train/test sets 
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.20,random_state=42)
    try:
        evaluate_regressor_model(model=rfr, X_test=X_test, y_test=y_test)
        
        
    except Exception as e:
        print(e)
# Out:
# shapes
# (2480, 115) (496, 113) (496,)
# how the model ranks the same feature subset
#                                    Feature         Model Weight
# 1                  gics_sector_Health Care                 0.05
# 2                        operatingExpenses                 0.05
# 3                              investments                 0.04
# 4                              commonStock                 0.04
# 5                   gics_sector_Financials                 0.03
# 6                              totalAssets                 0.03
# 7                      investmentIncomeNet                 0.03
# 8                         retainedEarnings                 0.03
# 9                    otherNonCurrentAssets                 0.03
# 10  accumulatedDepreciationAmortizationPPE                 0.03
# 11                   gics_sector_Materials                 0.03
# 12                               inventory                 0.03
# 13            gics_sector_Consumer Staples                 0.03
# 14                    changeInExchangeRate                 0.03
# 15                           current_ratio                 0.03
# 16       intangibleAssetsExcludingGoodwill                 0.03
# 17                         gics_sector_nan                 0.03
# 18                 gics_sector_Real Estate                 0.03
# 19      gics_sector_Information Technology                 0.03
# 20                    debt_to_equity_ratio                 0.03
# 21      gics_sector_Consumer Discretionary                 0.03
# 22                   cashflowFromFinancing                 0.03
# 23                            totalRevenue                 0.03
# 24                 gics_sector_Industrials                 0.03
# 25                      gics_sector_Energy                 0.03
# 26             comprehensiveIncomeNetOfTax                 0.03
# 27         sellingGeneralAndAdministrative                 0.03
# 28                   currentNetReceivables                 0.02
# 29                           shortTermDebt                 0.02
# 30          changeInCashAndCashEquivalents                 0.02
#
#
#
# sequence: 0
# shapes
# (2480, 115) (496, 113) (496,)
# Mean Absolute Error (MAE): 0.051150623613757835
# Mean Squared Error (MSE): 0.02684204474417064
# Root Mean Squared Error (RMSE): 0.1638354196874737
# Mean Absolute Percentage Error (MAPE): 21.94
# Accuracy: 78.06
# Score: 0.9429027635625478
#
#
#
# sequence: 1
# shapes
# (2480, 115) (496, 113) (496,)
# Mean Absolute Error (MAE): 0.06600403268089215
# Mean Squared Error (MSE): 0.024241889866895162
# Root Mean Squared Error (RMSE): 0.15569807277835895
# Mean Absolute Percentage Error (MAPE): 28.76
# Accuracy: 71.24
# Score: 0.9490000380573879
#
#
#
# sequence: 2
# shapes
# (2480, 115) (496, 113) (496,)
# Mean Absolute Error (MAE): 0.07790672048285702
# Mean Squared Error (MSE): 0.1211673046014844
# Root Mean Squared Error (RMSE): 0.34809094300410115
# Mean Absolute Percentage Error (MAPE): 24.22
# Accuracy: 75.78
# Score: 0.8328602664137027
#
#
#
# sequence: 3
# shapes
# (2480, 115) (496, 113) (496,)
# Mean Absolute Error (MAE): 0.08341056438176608
# Mean Squared Error (MSE): 0.15119602485644307
# Root Mean Squared Error (RMSE): 0.3888393303878134
# Mean Absolute Percentage Error (MAPE): 29.31
# Accuracy: 70.69
# Score: 0.8198449311669948
#
#
#
# sequence: 4
# shapes
# (2480, 115) (496, 113) (496,)
# Mean Absolute Error (MAE): 0.09834924726083204
# Mean Squared Error (MSE): 0.29409832791013096
# Root Mean Squared Error (RMSE): 0.5423083328791205
# Mean Absolute Percentage Error (MAPE): 20.65
# Accuracy: 79.35
# Score: 0.7279450191254966

# %%
#trying regressor models  

########################################################################################################
#train a generic Random Forest Regressor (default parameters) model to then look at model decay in future quarters 
#in other words, use the same model on successive quarters without retraining with new data. 
################################################################################################

dfout = prep_for_regressor(df)
#X,y=get_X_y_data(dfout,sequence=sequences[0])
X,y = get_X_y_data_regressor(dfout,sequence=0)

print('shapes')
print(X.shape,y.shape)

### starting ML ##############
#split into train/test sets 
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.20,random_state=42)
#train a "no frills Random Forest Classifier"
#rf = RandomForestClassifier(random_state=42)
#rf.fit(X_train,y_train)
#gbc =GradientBoostingClassifier(random_state=42)
#gbc.fit(X_train,y_train)
rfreg = RandomForestRegressor(random_state=42)
rfreg.fit(X_train,y_train)

#evaluate_model(model=rf, X_test=X_test, Y_test=y_test)

####################################################################################################
#look at decay.. accuracy, precision, recall, F1 scores without training a new model with new data
####################################################################################################
for j in range(len(sequences)):
    print('\n\n\nsequence:',j)
    #dfout,X,y = prep_for_classifier(df,sequence=sequences[j])
    X,y=get_X_y_data_regressor(dfout,sequence=sequences[j])
    print('shapes')
    print(dfout.shape,X.shape,y.shape)

    ### starting ML ##############
    #split into train/test sets 
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.20,random_state=42)
    y_pred = rfreg.predict(X_test)
    
    #source:https://stackoverflow.com/questions/50789508/random-forest-regression-how-do-i-analyse-its-performance-python-sklearn
    print('Mean Absolute Error (MAE):', metrics.mean_absolute_error(y_test, y_pred))
    print('Mean Squared Error (MSE):', metrics.mean_squared_error(y_test, y_pred))
    print('Root Mean Squared Error (RMSE):', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
    mape = np.mean(np.abs((y_test - y_pred) / np.abs(y_test)))
    print('Mean Absolute Percentage Error (MAPE):', round(mape * 100, 2))
    print('Accuracy:', round(100*(1 - mape), 2))
    print('Score:',r2_score(y_test, y_pred))
    #     #try:
    #    evaluate_model(model=rfreg, X_test=X_test, Y_test=y_test)
    #except Exception as e:
    #    print(e)
# Out:
# shapes
# (496, 113) (496,)
#
#
#
# sequence: 0
# shapes
# (2480, 115) (496, 113) (496,)
# Mean Absolute Error (MAE): 0.051150623613757835
# Mean Squared Error (MSE): 0.02684204474417064
# Root Mean Squared Error (RMSE): 0.1638354196874737
# Mean Absolute Percentage Error (MAPE): 21.94
# Accuracy: 78.06
# Score: 0.9429027635625478
#
#
#
# sequence: 1
# shapes
# (2480, 115) (496, 113) (496,)
# Mean Absolute Error (MAE): 0.06600403268089215
# Mean Squared Error (MSE): 0.024241889866895162
# Root Mean Squared Error (RMSE): 0.15569807277835895
# Mean Absolute Percentage Error (MAPE): 28.76
# Accuracy: 71.24
# Score: 0.9490000380573879
#
#
#
# sequence: 2
# shapes
# (2480, 115) (496, 113) (496,)
# Mean Absolute Error (MAE): 0.07790672048285702
# Mean Squared Error (MSE): 0.1211673046014844
# Root Mean Squared Error (RMSE): 0.34809094300410115
# Mean Absolute Percentage Error (MAPE): 24.22
# Accuracy: 75.78
# Score: 0.8328602664137027
#
#
#
# sequence: 3
# shapes
# (2480, 115) (496, 113) (496,)
# Mean Absolute Error (MAE): 0.08341056438176608
# Mean Squared Error (MSE): 0.15119602485644307
# Root Mean Squared Error (RMSE): 0.3888393303878134
# Mean Absolute Percentage Error (MAPE): 29.31
# Accuracy: 70.69
# Score: 0.8198449311669948
#
#
#
# sequence: 4
# shapes
# (2480, 115) (496, 113) (496,)
# Mean Absolute Error (MAE): 0.09834924726083204
# Mean Squared Error (MSE): 0.29409832791013096
# Root Mean Squared Error (RMSE): 0.5423083328791205
# Mean Absolute Percentage Error (MAPE): 20.65
# Accuracy: 79.35
# Score: 0.7279450191254966

# %%
#trying regressor models  

########################################################################################################
#train a generic Multiple Linear Regression (default parameters) model to then look at model decay in future quarters 
#in other words, use the same model on successive quarters without retraining with new data. 
################################################################################################


dfout = prep_for_regressor(df)
#X,y=get_X_y_data(dfout,sequence=sequences[0])
X,y = get_X_y_data_regressor(dfout,sequence=0)

print('shapes')
print(X.shape,y.shape)

### starting ML ##############
#split into train/test sets 
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.20,random_state=42)
#train a "no frills Random Forest Classifier"
#rf = RandomForestClassifier(random_state=42)
#rf.fit(X_train,y_train)
#gbc =GradientBoostingClassifier(random_state=42)
#gbc.fit(X_train,y_train)
lrreg = LinearRegression()
lrreg.fit(X_train,y_train)

#evaluate_model(model=rf, X_test=X_test, Y_test=y_test)

####################################################################################################
#look at decay.. accuracy, precision, recall, F1 scores without training a new model with new data
####################################################################################################
for j in range(len(sequences)):
    print('\n\n\nsequence:',j)
    #dfout,X,y = prep_for_classifier(df,sequence=sequences[j])
    X,y=get_X_y_data_regressor(dfout,sequence=sequences[j])
    print('shapes')
    print(dfout.shape,X.shape,y.shape)

    ### starting ML ##############
    #split into train/test sets 
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.20,random_state=42)
    y_pred = lrreg.predict(X_test)
    
    #source:https://stackoverflow.com/questions/50789508/random-forest-regression-how-do-i-analyse-its-performance-python-sklearn
    print('Mean Absolute Error (MAE):', metrics.mean_absolute_error(y_test, y_pred))
    print('Mean Squared Error (MSE):', metrics.mean_squared_error(y_test, y_pred))
    print('Root Mean Squared Error (RMSE):', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
    mape = np.mean(np.abs((y_test - y_pred) / np.abs(y_test)))
    print('Mean Absolute Percentage Error (MAPE):', round(mape * 100, 2))
    print('Accuracy:', round(100*(1 - mape), 2))
    print('Score:',r2_score(y_test, y_pred))
    #     #try:
    #    evaluate_model(model=rfreg, X_test=X_test, Y_test=y_test)
    #except Exception as e:
    #    print(e)
# Out:
# shapes
# (496, 113) (496,)
#
#
#
# sequence: 0
# shapes
# (2480, 115) (496, 113) (496,)
# Mean Absolute Error (MAE): 0.06117268250985035
# Mean Squared Error (MSE): 0.01622023335729561
# Root Mean Squared Error (RMSE): 0.12735867994485342
# Mean Absolute Percentage Error (MAPE): 42.6
# Accuracy: 57.4
# Score: 0.9654970212627603
#
#
#
# sequence: 1
# shapes
# (2480, 115) (496, 113) (496,)
# Mean Absolute Error (MAE): 0.07534905930093197
# Mean Squared Error (MSE): 0.014739012085810865
# Root Mean Squared Error (RMSE): 0.12140433306027781
# Mean Absolute Percentage Error (MAPE): 61.18
# Accuracy: 38.82
# Score: 0.9689921429568672
#
#
#
# sequence: 2
# shapes
# (2480, 115) (496, 113) (496,)
# Mean Absolute Error (MAE): 0.10138028834646926
# Mean Squared Error (MSE): 0.051630764019892667
# Root Mean Squared Error (RMSE): 0.2272240392649789
# Mean Absolute Percentage Error (MAPE): 44.94
# Accuracy: 55.06
# Score: 0.9287798620962628
#
#
#
# sequence: 3
# shapes
# (2480, 115) (496, 113) (496,)
# Mean Absolute Error (MAE): 0.07199297564365678
# Mean Squared Error (MSE): 0.018199641254467293
# Root Mean Squared Error (RMSE): 0.13490604602636344
# Mean Absolute Percentage Error (MAPE): 68.75
# Accuracy: 31.25
# Score: 0.9783145249615679
#
#
#
# sequence: 4
# shapes
# (2480, 115) (496, 113) (496,)
# Mean Absolute Error (MAE): 0.0833913891642451
# Mean Squared Error (MSE): 0.03111477707797036
# Root Mean Squared Error (RMSE): 0.17639381247076202
# Mean Absolute Percentage Error (MAPE): 31.5
# Accuracy: 68.5
# Score: 0.9712173471266782

# %%
# sequence: 3
# shapes
# (1984, 115) (496, 113) (496,)
# Mean Absolute Error (MAE): 0.0759207791400863
# Mean Squared Error (MSE): 0.10396274066219453
# Root Mean Squared Error (RMSE): 0.3224325366060233
# Mean Absolute Percentage Error (MAPE): 19.83
# Accuracy: 80.17
# Score: 0.8867528037666317
